# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
######1 zadanie
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 300)
y = np.cumsum(rng.randn(300, 6), 0)

# %%
plt.plot(x, y)
plt.legend('ABCDE', ncol=2, loc='lower left');

# %%
###### zadanie 2
import seaborn as sns
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

# %%
sns.distplot(data['x'])
sns.distplot(data['y']);
# Out:
# C:\Users\nurbe\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nurbe\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
###### zadanie 3
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['tip_percent'] = (100 * df['tip'] / df['total_bill'])
grid = sns.FacetGrid(df, row = "sex", col = "time", margin_titles = True)
grid.map(plt.hist, "tip_percent", bins = np.linspace(0, 40, 15))
plt.show()

# %%
###### zadanie 4 
n= int(input('enter celcius'))
F= n*1.18+32
print(F, 'temperature F')
# Out:
# enter celcius4
# 36.72 temperature F

# %%
###### zadanie 5

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#           Store    Country Region                 Date             Item  \
# 0        Moscow     Russia   EMEA  2018-10-06 00:00:00        Microwave
# 1       Toronto     Canada    NaN            4/23/2015        Microwave
# 2     Sao Paolo     Brazil  LATAM  2017-04-03 00:00:00  Air conditioner
# 3      Istanbul     Turkey   EMEA            8/14/2018      Ceiling fan
# 4        Sydney  Australia   APAC  2015-03-03 00:00:00          Toaster
# ...         ...        ...    ...                  ...              ...
# 2334     Vienna    Austria   EMEA           12/19/2017        Microwave
# 2335   Shenzhen      China   APAC            2/17/2015        Microwave
# 2336   Istanbul     Turkey   EMEA            5/27/2015  Washing Machine
# 2337     Athens     Greece   EMEA  2016-07-10 00:00:00   Coffee grinder
# 2338   Shanghai      China   APAC  2017-02-09 00:00:00        Microwave
#
#             Salesperson  List Price  Actual Price  Discount %
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339 entries, 0 to 2338
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         2339 non-null   object
#  1   Country       2339 non-null   object
#  2   Region        1946 non-null   object
#  3   Date          2339 non-null   object
#  4   Item          2339 non-null   object
#  5   Salesperson   2339 non-null   object
#  6   List Price    2339 non-null   int64
#  7   Actual Price  2339 non-null   int64
#  8   Discount %    2339 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 164.6+ KB

# %%
#1
a= df.groupby('Item')['Region'].count()
a
# Out:
# Item
# Air conditioner    162
# Blender            165
# Ceiling fan        146
# Coffee grinder     157
# Dishwasher         154
# Iron               195
# Microwave          172
# Oven               157
# Refrigerator       159
# Toaster            147
# Vacuum Cleaner     165
# Washing Machine    167
# Name: Region, dtype: int64

# %%
#2
y = np.array([df[df['Country']=="Saudi Arabia"]["Actual Price"].sum(), df[df['Country']=="China"]["Actual Price"].sum()])
mylabels = ["Saudi Arabia","China"]
plt.pie(y,labels = mylabels)
plt.show()

# %%
#3
df = df.loc[(df['Region'] == 'LATAM') | (df['Region'] == 'EMEA')]
df = df.groupby('Salesperson').agg({'Discount %':'mean'})
df = df.sort_values(by = "Discount %", ascending= True)
print(df.iloc[0])
# Out:
# Discount %    0.0
# Name: Fiona Johnson, dtype: float64

# %%
#4
plt.hist(a)
plt.show()
##For 1st

plt.pie(y,labels = mylabels)
plt.show() 
##For 2nd

df.iloc[0:20].plot.bar()
##For 3rd
# Out:
# <AxesSubplot:xlabel='Salesperson'>
